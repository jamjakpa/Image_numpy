# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL  import Image

# %%
pic = Image.open('C:/...../00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# TRANSFORM THE JPEG IN AN NUMPY ARRAY

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %% [markdown]
# above you see the Height, Width, colorchannels

# %%
#plt.imshow shows images that are transformed to as arrays
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (1300, 1950, 3)

# %%
# R G B #[1300,1950,Green]
#Red channel
#pic_red[:,:,0] # Values all between 0 - 255 
plt.imshow(pic_red[:,:,0])
